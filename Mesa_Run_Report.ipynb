# %% [markdown]
# # MESA-Web: Output Summary
# First-look overview of a MESA run

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path
import mesa_web as mw, mesaUtils as mu

# %% [markdown]
# ### Read in Configuration and History Data; plot HR diagram, H-depletion, and time-evolution

# %%
# 0.5M  MESA-Web_Job_11222321846; 1.0M 48; 15M 50
folder_name = 'MESA-Web_Job_11242321912'               # folder must be in current working directory
mesaPath = Path.cwd() / folder_name  
mesaConfig = mu.get_mesaConfig(mesaPath / 'input.txt')
hist = mw.read_history(mesaPath / 'trimmed_history.data')
print('Job: ', mesaConfig['Job'], '|  Initial Mass: ', mesaConfig['Initial Mass'], '|  Metallicity: ', mesaConfig['Initial Metallicity'])
# Out:
# Job:  11242321912 |  Initial Mass:   15 (solar mass) |  Metallicity:   0.02

# %%
mu.plotMesa(folder_name, mesaConfig,hist)
